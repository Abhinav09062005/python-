# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#type od data
# numerical and categorical data
# data visualization
# plotli & tablu


#bivariate analysis
# categorical-> numerical and numerical -> numerical

#use case-> time series data

# plotting a simple function
price=[48000,57000,47000,45000,55000,60000]
year=[2015,2016,2017,2018,2019,2020]
plt.plot(year,price)

# %%
#from a pandas dataframe
batsman=pd.read_csv('sharma-kohli.csv')
batsman
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364
# 5   2013        538      639
# 6   2014        390      359
# 7   2015        482      505
# 8   2016        489      973
# 9   2017        333      308

# %%
plt.plot(batsman['index'],batsman['V Kohli'],color='blue',linestyle='dashdot',linewidth=3,marker='D')
plt.plot(batsman['index'],batsman['RG Sharma'],color='red',linestyle='solid',linewidth=1,marker='>')

plt.title('rohit vs virat')
plt.xlabel('season')
plt.ylabel('runs')
# Out:
# Text(0, 0.5, 'runs')

# %%
plt.plot(batsman['index'],batsman['V Kohli'],color='blue',linestyle='dashdot',linewidth=3,marker='D',label='virat')
plt.plot(batsman['index'],batsman['RG Sharma'],color='red',linestyle='solid',linewidth=1,marker='>',label='rohit')

plt.title('rohit vs virat')
plt.xlabel('season')
plt.ylabel('runs')

plt.legend(loc='best')

# %%
#limiting axes
price=[48000,57000,47000,45000,55000,60000,4000000]
year=[2015,2016,2017,2018,2019,2020,2021]
plt.plot(year,price)
plt.ylim(0,100000)
# Out:
# (0.0, 100000.0)

# %%
# grid
plt.plot(batsman['index'],batsman['V Kohli'],color='blue',linestyle='dashdot',linewidth=3,marker='D',label='virat')
plt.plot(batsman['index'],batsman['RG Sharma'],color='red',linestyle='solid',linewidth=1,marker='>',label='rohit')

plt.title('rohit vs virat')
plt.xlabel('season')
plt.ylabel('runs')

plt.legend(loc='best')
plt.grid()

# %%
#show ye graph ko plot krwata h 
plt.show()

# %%
# scatter plot -> use in bivariatee analysis for 2 col
#-> numerical vs numerical best use
# use case-> finding correlation

x=np.linspace(-10 ,10,50)
y=10*x+3+np.random.randint(0,300,50)

# %%
plt.xlabel('x value')
plt.ylabel('y label')
plt.title('x vs y')
plt.scatter(x,y)
plt.legend(loc='best')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_27184\3674323821.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc='best')

# %%
plt.show()

# %%
plt.plot(x)
plt.plot(y)

# %%
df=pd.read_csv("batter.csv")
df=df.head(50)
df
# Out:
#             batter  runs        avg  strike_rate
# 0          V Kohli  6634  36.251366   125.977972
# 1         S Dhawan  6244  34.882682   122.840842
# 2        DA Warner  5883  41.429577   136.401577
# 3        RG Sharma  5881  30.314433   126.964594
# 4         SK Raina  5536  32.374269   132.535312
# 5   AB de Villiers  5181  39.853846   148.580442
# 6         CH Gayle  4997  39.658730   142.121729
# 7         MS Dhoni  4978  39.196850   130.931089
# 8       RV Uthappa  4954  27.522222   126.152279
# 9       KD Karthik  4377  26.852761   129.267572
# 10       G Gambhir  4217  31.007353   119.665153
# 11       AT Rayudu  4190  28.896552   124.148148
# 12       AM Rahane  4074  30.863636   117.575758
# 13        KL Rahul  3895  46.927711   132.799182
# 14       SR Watson  3880  30.793651   134.163209
# 15       MK Pandey  3657  29.731707   117.739858
# 16       SV Samson  3526  29.140496   132.407060
# 17      KA Pollard  3437  28.404959   140.457703
# ...

# %%
plt.scatter(df['avg'],df['strike_rate'],marker="+",color='red')
plt.title('avg and strike rate')
plt.xlabel('avg')
plt.ylabel('strike_rate')
# Out:
# Text(0, 0.5, 'strike_rate')

# %%
# scatterplot using plt.plot
#it is very fast than scaterplot but we can chnage the colr
plt.plot(df['avg'],df['strike_rate'],'o')
